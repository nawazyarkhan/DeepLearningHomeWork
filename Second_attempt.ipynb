# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df.drop('EIN', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-ce9c9f073859> in <module>
#       1 # Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#       2 #  YOUR CODE GOES HERE
# ----> 3 application_df.drop('EIN', axis=1, inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['EIN'] not found in axis"

# %%
application_df.drop('NAME', axis=1, inplace=True)

# %%
application_df.head()

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_cnt_df=application_df['APPLICATION_TYPE'].value_counts()
application_cnt_df
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = []
for index, val in application_cnt_df.items():
    if val <= 500:
        application_types_to_replace.append(index)


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
classifications_count_df=application_df['CLASSIFICATION'].value_counts()
classifications_count_df
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C8210        1
# C1732        1
# C2190        1
# C2380        1
# C1370        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df["CLASSIFICATION"].value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1600        5
# C1257        5
# C1260        3
# C2710        3
# C0           3
# C1234        2
# C3200        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = []
for index, val in classifications_count_df.items():
    if val <= 1800:
        classifications_to_replace.append(index)
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
numeric_df=pd.get_dummies(application_df)
numeric_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays

y = numeric_df["IS_SUCCESSFUL"]
X = numeric_df.drop("IS_SUCCESSFUL", axis=1)

# Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(X.shape)
print(y.shape)
# Out:
# (34299, 43)
# (34299,)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=43))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 5)                 220
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 256
# Trainable params: 256
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6429 - accuracy: 0.6663
# Epoch 2/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5895 - accuracy: 0.7248
# Epoch 3/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5766 - accuracy: 0.7253
# Epoch 4/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5717 - accuracy: 0.7247
# Epoch 5/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5677 - accuracy: 0.7261
# Epoch 6/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5653 - accuracy: 0.7264
# Epoch 7/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5638 - accuracy: 0.7266
# Epoch 8/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5625 - accuracy: 0.7252
# Epoch 9/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5611 - accuracy: 0.7274
# Epoch 10/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5606 - accuracy: 0.7286
# Epoch 11/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5600 - accuracy: 0.7269
# Epoch 12/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5593 - accuracy: 0.7291
# Epoch 13/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5592 - accuracy: 0.7274
# Epoch 14/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5583 - accuracy: 0.7276
# Epoch 15/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5581 - accuracy: 0.7280
# Epoch 16/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5577 - accuracy: 0.7280
# Epoch 17/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5574 - accuracy: 0.7276
# Epoch 18/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5573 - accuracy: 0.7282
# Epoch 19/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5571 - accuracy: 0.7286
# Epoch 20/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5571 - accuracy: 0.7270
# Epoch 21/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5568 - accuracy: 0.7282
# Epoch 22/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5566 - accuracy: 0.7273
# Epoch 23/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5565 - accuracy: 0.7283
# Epoch 24/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5565 - accuracy: 0.7269
# Epoch 25/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7283
# Epoch 26/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5559 - accuracy: 0.7280
# Epoch 27/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5561 - accuracy: 0.7280
# Epoch 28/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5557 - accuracy: 0.7276
# Epoch 29/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5555 - accuracy: 0.7272
# Epoch 30/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5556 - accuracy: 0.7278
# Epoch 31/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5551 - accuracy: 0.7287
# Epoch 32/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5552 - accuracy: 0.7278
# Epoch 33/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5550 - accuracy: 0.7286
# Epoch 34/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5547 - accuracy: 0.7292
# Epoch 35/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5550 - accuracy: 0.7279
# Epoch 36/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5547 - accuracy: 0.7276
# Epoch 37/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5546 - accuracy: 0.7276
# Epoch 38/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5545 - accuracy: 0.7294
# Epoch 39/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5543 - accuracy: 0.7286
# Epoch 40/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5544 - accuracy: 0.7298
# Epoch 41/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5540 - accuracy: 0.7285
# Epoch 42/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5538 - accuracy: 0.7292
# Epoch 43/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5537 - accuracy: 0.7296
# Epoch 44/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5537 - accuracy: 0.7292
# Epoch 45/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5537 - accuracy: 0.7285
# Epoch 46/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5535 - accuracy: 0.7300
# Epoch 47/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5534 - accuracy: 0.7286
# Epoch 48/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5534 - accuracy: 0.7297
# Epoch 49/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5533 - accuracy: 0.7296
# Epoch 50/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5530 - accuracy: 0.7294
# Epoch 51/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5531 - accuracy: 0.7296
# Epoch 52/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.7290
# Epoch 53/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5527 - accuracy: 0.7297
# Epoch 54/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5527 - accuracy: 0.7288
# Epoch 55/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5529 - accuracy: 0.7291
# Epoch 56/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5527 - accuracy: 0.7298
# Epoch 57/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5526 - accuracy: 0.7302
# Epoch 58/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5526 - accuracy: 0.7292
# Epoch 59/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5525 - accuracy: 0.7287
# Epoch 60/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.7289
# Epoch 61/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.7294
# Epoch 62/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5523 - accuracy: 0.7294
# Epoch 63/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.7299
# Epoch 64/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5523 - accuracy: 0.7306
# Epoch 65/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5521 - accuracy: 0.7293
# Epoch 66/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7295
# Epoch 67/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.7302
# Epoch 68/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5521 - accuracy: 0.7297
# Epoch 69/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5523 - accuracy: 0.7296
# Epoch 70/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5525 - accuracy: 0.7289
# Epoch 71/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5521 - accuracy: 0.7304
# Epoch 72/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5520 - accuracy: 0.7295
# Epoch 73/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5519 - accuracy: 0.7300
# Epoch 74/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5519 - accuracy: 0.7308
# Epoch 75/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5517 - accuracy: 0.7299
# Epoch 76/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5519 - accuracy: 0.7302
# Epoch 77/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5517 - accuracy: 0.7305
# Epoch 78/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7299
# Epoch 79/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5517 - accuracy: 0.7310
# Epoch 80/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5517 - accuracy: 0.7305
# Epoch 81/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5516 - accuracy: 0.7311
# Epoch 82/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7298
# Epoch 83/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7311
# Epoch 84/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7299
# Epoch 85/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7302
# Epoch 86/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5517 - accuracy: 0.7299
# Epoch 87/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5519 - accuracy: 0.7307
# Epoch 88/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5513 - accuracy: 0.7314
# Epoch 89/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7302
# Epoch 90/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7312
# Epoch 91/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5513 - accuracy: 0.7310
# Epoch 92/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5513 - accuracy: 0.7316
# Epoch 93/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7305
# Epoch 94/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7306
# Epoch 95/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7304
# Epoch 96/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7304
# Epoch 97/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5513 - accuracy: 0.7311
# Epoch 98/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7300
# Epoch 99/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5513 - accuracy: 0.7310
# Epoch 100/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7308
# Epoch 101/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7303
# Epoch 102/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7303
# Epoch 103/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7312
# Epoch 104/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7309
# Epoch 105/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5513 - accuracy: 0.7309
# Epoch 106/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5511 - accuracy: 0.73 - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7305
# Epoch 107/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7315
# Epoch 108/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7312
# Epoch 109/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7305
# Epoch 110/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5513 - accuracy: 0.7306
# Epoch 111/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7315
# Epoch 112/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7304
# Epoch 113/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7311
# Epoch 114/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7311
# Epoch 115/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7301
# Epoch 116/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7319
# Epoch 117/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7307
# Epoch 118/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7304
# Epoch 119/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7308
# Epoch 120/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7307
# Epoch 121/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7315
# Epoch 122/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7314
# Epoch 123/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7313
# Epoch 124/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7309
# Epoch 125/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7315
# Epoch 126/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7305
# Epoch 127/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7306
# Epoch 128/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5509 - accuracy: 0.7313
# Epoch 129/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7306
# Epoch 130/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7315
# Epoch 131/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7302
# Epoch 132/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7307
# Epoch 133/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7317
# Epoch 134/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7308
# Epoch 135/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7309
# Epoch 136/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7320
# Epoch 137/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7311
# Epoch 138/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7315
# Epoch 139/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7304
# Epoch 140/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7311
# Epoch 141/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7320
# Epoch 142/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7320
# Epoch 143/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7312
# Epoch 144/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7307
# Epoch 145/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7306
# Epoch 146/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7317
# Epoch 147/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7310
# Epoch 148/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7311
# Epoch 149/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5517 - accuracy: 0.7299
# Epoch 150/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7312
# Epoch 151/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7302
# Epoch 152/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7307
# Epoch 153/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7312
# Epoch 154/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7308
# Epoch 155/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7310
# Epoch 156/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7304
# Epoch 157/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7317
# Epoch 158/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7313
# Epoch 159/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7306
# Epoch 160/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7308
# Epoch 161/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7312
# Epoch 162/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5510 - accuracy: 0.7309
# Epoch 163/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7308
# Epoch 164/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7313
# Epoch 165/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7322
# Epoch 166/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7306
# Epoch 167/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7306
# Epoch 168/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7305
# Epoch 169/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7306
# Epoch 170/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7301
# Epoch 171/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7309
# Epoch 172/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7296
# Epoch 173/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7301
# Epoch 174/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7306
# Epoch 175/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7314
# Epoch 176/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7312
# Epoch 177/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7308
# Epoch 178/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7308
# Epoch 179/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5510 - accuracy: 0.7304
# Epoch 180/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7307
# Epoch 181/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7314
# Epoch 182/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7315
# Epoch 183/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7308
# Epoch 184/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7307
# Epoch 185/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7307
# Epoch 186/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7303
# Epoch 187/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7308
# Epoch 188/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5507 - accuracy: 0.7308
# Epoch 189/200
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5512 - accuracy: 0.7303
# Epoch 190/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7307
# Epoch 191/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5507 - accuracy: 0.7304
# Epoch 192/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7306
# Epoch 193/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7309
# Epoch 194/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7308
# Epoch 195/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7308
# Epoch 196/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7307
# Epoch 197/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7315
# Epoch 198/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7315
# Epoch 199/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7296
# Epoch 200/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5509 - accuracy: 0.7315

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5589 - accuracy: 0.7271
# Loss: 0.5588899850845337, Accuracy: 0.7271137237548828

# %%
# Export our model to HDF5 file
nn_model.save("AlphabetSoupCharity2.h5")

# %% [markdown]
# I have tried adding a third layer and then forth layer but can't see accuracy going anyway better than .73.
# All i can imagine that improvement can be made using:
# - adding more neuron in hidden layer
# - adding more epochs for doing itterations
